# %%
a = "apple"
b = "apple"
c = a
print(id(a), type(a))
print(id(b), type(b))
print(id(c), type(c))
# Out:
# 4434986736 <class 'str'>
# 4434986736 <class 'str'>
# 4434986736 <class 'str'>

# %%
i = 0
while i < 5:
    if i == 1:
        continue
    if i == 2:
        break
    print(i)
    i += 1

# %%
def add (a: int, b:int) -> int:
    """
    Function to add two integer
    """
    return a+b

pythonic_add = lambda a,b : a+b

# %%
print(add(1, 2))
print(pythonic_add(1,2))
# Out:
# 3
# 3

# %%
lst = [1,2,3,4]

# %%
lst.append(5)
lst.insert(0,8)

# %%
print(lst)
# Out:
# [8, 8, 0, 1, 2, 3, 4, 5, 5, 8, 5, 5, 5, 8, 5]

# %%
my_dict = {}

# %%
my_dict.update({'a': 1})
my_dict.update(b

# %%
print(list(x for x in range(5)))
# Out:
# [0, 1, 2, 3, 4]
